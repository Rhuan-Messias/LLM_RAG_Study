# %%
import tiktoken

# %%
encoder = tiktoken.get_encoding('gpt2')

# %%
code = encoder.encode("My name is something")
print(code)
print(len(code))
# Out:
# [3666, 1438, 318, 1223]
# 4

# %%
decoded = encoder.decode(code)
print(decoded)
# Out:
# My name is something
